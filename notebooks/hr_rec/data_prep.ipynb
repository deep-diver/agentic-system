# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# ## Generate synthetic mock-up dataset

# %% [markdown]
# ### Setup endpoint and client

# %%
from openai import OpenAI

model_name = "solar-pro-250422"

# Configure OpenAI client to use Upstage API
client = OpenAI(
    base_url="https://api.upstage.ai/v1",
    api_key=os.getenv("UPSTAGE_API_KEY")
)

# %% [markdown]
# ### Variables

# %%
projects_data = []
num_projects = 100

# %% [markdown]
# ### JSON schema for structured output

# %%
# Schema for project generation
project_schema = {
    "type": "object",
    "properties": {
        "project_name": {"type": "string"},
        "descriptive_summary": {"type": "string"},
        "required_roles": {
            "type": "array",
            "items": {"type": "string"}
        },
        "duration_months": {"type": "integer"},
    },
    "required": ["project_name", "descriptive_summary", "required_roles"]
}

# Schema for participant generation
participant_schema = {
    "type": "object",
    "properties": {
        "participants": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "name": {"type": "string"},
                    "role": {"type": "string"},
                    "experience_years": {"type": "integer"},
                    "skills": {
                        "type": "array",
                        "items": {"type": "string"}
                    },
                    "performance_rating": {"type": "number", "minimum": 1, "maximum": 5}
                },
                "required": ["name", "role", "experience_years", "skills"]
            }
        }
    },
    "required": ["participants"]
}

# %% [markdown]
# ### generate data (project and participants per project)

# %%
for i in range(num_projects):
    print(f"Generating project {i+1}/{num_projects}...")
    
    # Prepare context about previously generated projects
    previous_projects_context = ""
    if i > 0:
        previous_summaries = [proj['descriptive_summary'] for proj in projects_data]
        previous_projects_context = f"\n\nPreviously generated projects to avoid duplication:\n" + "\n".join([f"- {summary}" for summary in previous_summaries])
    
    # Generate project
    project_response = client.chat.completions.create(
        model=model_name,
        messages=[
            {
                "role": "system",
                "content": "You are a project manager creating realistic software development projects. Generate diverse projects across different industries and complexity levels."
            },
            {
                "role": "user",
                "content": f"Generate a detailed software development project (project #{i+1}). Include a descriptive summary, required roles, and other relevant project details.{previous_projects_context}"
            }
        ],
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "project_schema",
                "schema": project_schema
            }
        }
    )
    
    project = project_response.choices[0].message.content
    project_data = eval(project)  # In production, use json.loads() with proper error handling
    
    print(f"Project: {project_data['project_name']}")
    print(f"Required roles: {', '.join(project_data['required_roles'])}")
    
    # Generate participants for this project
    participants_response = client.chat.completions.create(
        model=model_name,
        messages=[
            {
                "role": "system",
                "content": "You are an HR manager creating realistic participant profiles for software projects. Generate diverse participants with varying experience levels and skills."
            },
            {
                "role": "user",
                "content": f"Generate participants for the project '{project_data['project_name']}' with the following required roles: {', '.join(project_data['required_roles'])}. Create one participant for each required role."
            }
        ],
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "participant_schema",
                "schema": participant_schema
            }
        }
    )
    
    participants = participants_response.choices[0].message.content
    participants_data = eval(participants)  # In production, use json.loads() with proper error handling
    
    # Combine project and participants data
    project_data['participants'] = participants_data['participants']
    projects_data.append(project_data)
    
    print(f"Generated {len(participants_data['participants'])} participants")
    print("-" * 50)

print(f"\nGenerated {len(projects_data)} projects with participants!")
# Out:
# Generating project 1/100...
# Project: Smart Health Monitoring App
# Required roles: Project Manager, Mobile App Developer, Backend Developer, Frontend Developer, UI/UX Designer, Quality Assurance Engineer, Healthcare Consultant, Security Specialist
# Generated 8 participants
# --------------------------------------------------
# Generating project 2/100...
# Project: Smart Inventory Management System
# Required roles: Project Manager, Business Analyst, Cloud Architect, Backend Developer, Frontend Developer, Mobile App Developer, IoT Specialist, Data Scientist, Security Specialist, Quality Assurance Engineer
# Generated 10 participants
# --------------------------------------------------
# Generating project 3/100...
# Project: FinanceGenius
# Required roles: Software Developer, Project Manager, UX/UI Designer, AI Specialist, Product Manager, Quality Assurance Engineer
# Generated 6 participants
# --------------------------------------------------
# Generating project 4/100...
# Project: Smart City Traffic Management System
# Required roles: Project Manager, UI/UX Designer, Mobile Application Developer, Backend Developer, Frontend Developer, AI Specialist, IoT Engineer, Security Expert, Quality Assurance Tester, DevOps Engineer
# Generated 10 participants
# --------------------------------------------------
# Generating project 5/100...
# Project: VR Industrial Safety Training Platform
# Required roles: Software Developer, VR Developer, UI/UX Designer, Project Manager, Quality Assurance Tester
# Generated 5 participants
# --------------------------------------------------
# Generating project 6/100...
# Project: Sustainable Agriculture Platform
# Required roles: Full-Stack Developer, AI Specialist, IoT Engineer, Mobile App Developer, Data Security Expert
# Generated 5 participants
# --------------------------------------------------
# Generating project 7/100...
# Project: Blockchain-Based Supply Chain Transparency Platform
# Required roles: Blockchain Developer, Front-End Developer, Back-End Developer, Security Expert, UI/UX Designer
# Generated 5 participants
# --------------------------------------------------
# Generating project 8/100...
# Project: Educational Gamification Platform
# Required roles: Educational Content Developer, UI/UX Designer, Front-End Developer, Back-End Developer, Database Administrator, Security Specialist, Project Manager
# Generated 7 participants
# --------------------------------------------------
# Generating project 9/100...
# Project: Project #9: AI-Enhanced Customer Support Chatbot
# Required roles: AI Engineer, Chatbot Developer, UI/UX Designer, Backend Developer, Frontend Developer, CRM Integration Specialist, Data Security Expert
# Generated 7 participants
# --------------------------------------------------
# Generating project 10/100...
# Project: Project #10
# Required roles: AI Engineer, Financial Advisor, Backend Developer, Frontend Developer, Security Specialist, Project Manager
# Generated 6 participants
# --------------------------------------------------
# Generating project 11/100...
# Project: Project #11: AI-Powered Chatbot for E-commerce Platforms
# Required roles: Project Manager, AI Engineer, Chatbot Developer, Front-end Developer, Back-end Developer, DevOps Engineer, QA Analyst, Data Protection Officer
# Generated 8 participants
# --------------------------------------------------
# Generating project 12/100...
# Project: Agritech IoT Ecosystem
# Required roles: IoT Developer, AI Specialist, Farming Consultant, Mobile App Developer, Web Developer, Data Security Expert
# Generated 6 participants
# --------------------------------------------------
# Generating project 13/100...
# Project: Smart Home Energy Management System
# Required roles: Project Manager, IoT Engineer, AI Specialist, Mobile App Developer, Web Developer, Security Expert
# Generated 6 participants
# --------------------------------------------------
# Generating project 14/100...
# Project: AI-Enhanced Online Learning Platform
# Required roles: Project Manager, UI/UX Designer, Front-End Developer, Back-End Developer, AI Specialist, Educational Consultant
# Generated 6 participants
# --------------------------------------------------
# Generating project 15/100...
# Project: Project #15: AI-Enhanced Cybersecurity Platform
# Required roles: AI Developer, Cybersecurity Specialist, Software Architect, Project Manager, QA Engineer
# Generated 5 participants
# --------------------------------------------------
# Generating project 16/100...
# Project: Project #16: AI-Powered Supply Chain Optimization Platform
# Required roles: Software Developer, AI Specialist, Systems Integrator, Data Security Expert, Supply Chain Analyst
# Generated 5 participants
# --------------------------------------------------
# Generating project 17/100...
# Project: AI-Driven Cybersecurity Platform
# Required roles: Security Engineer, AI Developer, Backend Developer, Data Scientist, DevOps Engineer
# Generated 5 participants
# --------------------------------------------------
# Generating project 18/100...
# Project: Project #18: AI-Powered Talent Acquisition Platform
# Required roles: Project Manager, AI Specialist, Machine Learning Engineer, HR Software Developer, UX/UI Designer, Security Expert
# Generated 6 participants
# --------------------------------------------------
# Generating project 19/100...
# Project: AI-driven Cybersecurity Platform for Enterprise Threat Detection and Response
# Required roles: Senior AI Engineer, Cybersecurity Specialist, Software Developer, Project Manager
# Generated 4 participants
# --------------------------------------------------
# Generating project 20/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: Software Developer, AI Specialist, Data Security Expert, Financial Consultant
# Generated 4 participants
# --------------------------------------------------
# Generating project 21/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Developer, Financial Analyst, Security Specialist
# Generated 3 participants
# --------------------------------------------------
# Generating project 22/100...
# Project: Project #22: AI-Driven Personal Finance Management Platform
# Required roles: Project Manager, Software Developer, AI Specialist, Data Scientist, UI/UX Designer, Quality Assurance Engineer, Backend Developer, Frontend Developer, Mobile App Developer, Security Analyst
# Generated 10 participants
# --------------------------------------------------
# Generating project 23/100...
# Project: Project #23
# Required roles: AI Specialist, Financial Analyst, Security Expert, Regulatory Compliance Officer, UI/UX Designer
# Generated 5 participants
# --------------------------------------------------
# Generating project 24/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, UI/UX Designer, Backend Developer, Frontend Developer, AI Specialist, Cybersecurity Expert, Banking API Integration Specialist
# Generated 7 participants
# --------------------------------------------------
# Generating project 25/100...
# Project: Project #25: AI-Powered Supply Chain Optimization Platform
# Required roles: Project Manager, Business Analyst, AI/ML Engineer, Backend Developer, Frontend Developer, QA Engineer, DevOps Engineer
# Generated 7 participants
# --------------------------------------------------
# Generating project 26/100...
# Project: Project #26: AI-Driven Personal Finance Management Platform
# Required roles: AI Engineer, Backend Developer, Frontend Developer, Security Specialist, Financial Consultant
# Generated 5 participants
# --------------------------------------------------
# Generating project 27/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: Project Manager, AI Specialist, Financial Analyst, Frontend Developer, Backend Developer, QA Engineer, Security Specialist
# Generated 7 participants
# --------------------------------------------------
# Generating project 28/100...
# Project: FinanceOptimizer
# Required roles: Project Manager, AI Specialist, Financial Analyst, Frontend Developer, Backend Developer, QA Engineer, Security Specialist
# Generated 7 participants
# --------------------------------------------------
# Generating project 29/100...
# Project: Smart Home Energy Management System
# Required roles: IoT Developer, AI Specialist, Mobile App Developer, Web Developer, Security Expert
# Generated 5 participants
# --------------------------------------------------
# Generating project 30/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Engineer, Data Scientist, Financial Analyst, Software Developer, UI/UX Designer, Security Specialist, Compliance Officer
# Generated 7 participants
# --------------------------------------------------
# Generating project 31/100...
# Project: Project #31: AI-Driven Personal Finance Management Platform
# Required roles: Project Manager, UI/UX Designer, Frontend Developer, Backend Developer, AI/Machine Learning Engineer, Security Specialist, Compliance Officer, Quality Assurance Engineer
# Generated 8 participants
# --------------------------------------------------
# Generating project 32/100...
# Project: AI-driven Cybersecurity Platform for Enterprise Threat Detection and Response
# Required roles: Data Scientist, AI Developer, Cybersecurity Specialist, Systems Integrator, Software Engineer
# Generated 5 participants
# --------------------------------------------------
# Generating project 33/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, AI Engineer, Frontend Developer, Backend Developer, Full Stack Developer, Quality Assurance Engineer, UX/UI Designer, Business Analyst, Security Expert
# Generated 9 participants
# --------------------------------------------------
# Generating project 34/100...
# Project: Project #34
# Required roles: Project Manager, Business Analyst, UI/UX Designer, Front-End Developer, Back-End Developer, AI/ML Engineer, QA Engineer, Security Specialist, Compliance Officer
# Generated 9 participants
# --------------------------------------------------
# Generating project 35/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, Senior Software Developer, AI/ML Engineer, Financial Analyst, Security Specialist, UX/UI Designer
# Generated 6 participants
# --------------------------------------------------
# Generating project 36/100...
# Project: AI-Enhanced Virtual Assistant for Customer Service
# Required roles: AI Engineer, Front-End Developer, Back-End Developer, Security Specialist, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 37/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, AI Engineer, Backend Developer, Frontend Developer, Security Specialist, Compliance Officer
# Generated 6 participants
# --------------------------------------------------
# Generating project 38/100...
# Project: Project #38: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, Business Analyst, UI/UX Designer, Frontend Developer, Backend Developer, AI/ML Engineer, Security Specialist, QA Engineer
# Generated 8 participants
# --------------------------------------------------
# Generating project 39/100...
# Project: Project #39 - AI-Powered Virtual Assistant for Customer Service
# Required roles: AI Engineer, Machine Learning Specialist, Natural Language Processing (NLP) Expert, CRM System Integration Specialist, Data Security Expert, Multi-language Support Specialist
# Generated 6 participants
# --------------------------------------------------
# Generating project 40/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Engineer, Backend Developer, Frontend Developer, Security Specialist, Regulatory Compliance Expert
# Generated 5 participants
# --------------------------------------------------
# Generating project 41/100...
# Project: Project #41: AI-driven Personal Finance Management Platform
# Required roles: Project Manager, Business Analyst, UI/UX Designer, Backend Developer, Frontend Developer, AI/ML Engineer, Quality Assurance Engineer, Security Specialist, Legal Consultant
# Generated 9 participants
# --------------------------------------------------
# Generating project 42/100...
# Project: Project #42
# Required roles: Project Manager, Business Analyst, UX/UI Designer, Backend Developer, Frontend Developer, AI Engineer, Security Specialist
# Generated 7 participants
# --------------------------------------------------
# Generating project 43/100...
# Project: Project #43
# Required roles: Project Manager, Business Analyst, AI Engineer, Backend Developer, Frontend Developer, Quality Assurance Engineer, Security Specialist, Compliance Officer
# Generated 8 participants
# --------------------------------------------------
# Generating project 44/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Engineer, Software Developer, UI/UX Designer, Backend Developer, Frontend Developer, Quality Assurance Engineer, Data Security Specialist, Financial Compliance Officer
# Generated 8 participants
# --------------------------------------------------
# Generating project 45/100...
# Project: Project #45: AI-Driven Personal Finance Management Platform
# Required roles: AI Engineer, Backend Developer, Frontend Developer, Security Specialist, Financial Consultant, Regulatory Compliance Officer
# Generated 6 participants
# --------------------------------------------------
# Generating project 46/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Engineer, Backend Developer, Frontend Developer, Security Specialist, Financial Compliance Analyst
# Generated 5 participants
# --------------------------------------------------
# Generating project 47/100...
# Project: Project #47
# Required roles: Project Manager, AI Engineer, Financial Analyst, Frontend Developer, Backend Developer, QA Engineer, Security Specialist, Regulatory Compliance Officer
# Generated 8 participants
# --------------------------------------------------
# Generating project 48/100...
# Project: Project #48: AI-driven Personal Finance Management Platform
# Required roles: AI Engineer, Financial Analyst, Data Scientist, Backend Developer, Frontend Developer, Cybersecurity Specialist, Regulatory Compliance Officer
# Generated 7 participants
# --------------------------------------------------
# Generating project 49/100...
# Project: Project #49: AI-Driven Personal Finance Management Platform
# Required roles: Software Developer, AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert
# Generated 5 participants
# --------------------------------------------------
# Generating project 50/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Engineer, Financial Advisor, Data Security Specialist, Frontend Developer, Backend Developer, UI/UX Designer
# Generated 6 participants
# --------------------------------------------------
# Generating project 51/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Backend Developer, Frontend Developer, Security Expert, Financial Regulations Consultant
# Generated 5 participants
# --------------------------------------------------
# Generating project 52/100...
# Project: Project #52: AI-Enhanced Smart City Traffic Management System
# Required roles: AI Specialist, IoT Engineer, Traffic Engineer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 53/100...
# Project: Smart City Traffic Management System
# Required roles: AI Specialist, IoT Engineer, Traffic Engineer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 54/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 55/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 56/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 57/100...
# Project: Project #57: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 58/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 59/100...
# Project: Project #59: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 60/100...
# Project: Project #60: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 61/100...
# Project: AI-Powered Virtual Assistant for Customer Service
# Required roles: AI Specialist, CRM Expert, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 62/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 63/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 64/100...
# Project: Project #64: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 65/100...
# Project: Project #65
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 66/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 67/100...
# Project: Project #67: AI-Powered Virtual Assistant for Customer Service
# Required roles: AI Specialist, CRM Expert, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 68/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 69/100...
# Project: Project #69: AI-Powered Virtual Assistant for Multilingual Customer Service
# Required roles: AI Specialist, CRM Expert, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 70/100...
# Project: AI-Powered Virtual Assistant for Customer Service
# Required roles: AI Specialist, CRM Expert, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 71/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 72/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 73/100...
# Project: Project #73
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 74/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 75/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 76/100...
# Project: Project #76
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 77/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 78/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 79/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 80/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 81/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 82/100...
# Project: AI-Driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 83/100...
# Project: AI-Powered Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 84/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 85/100...
# Project: AI-driven Personal Finance Management Platform
# Required roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, Project Manager
# Generated 5 participants
# --------------------------------------------------
# Generating project 86/100...
# Traceback (most recent call last):
#
#   File /opt/miniconda3/envs/agentic-system/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[29], line 86
#     project_data = eval(project)  # In production, use json.loads() with proper error handling
#
#   File <string>:3
#     "descriptive_summary": "Develop an AI-driven personal finance management platform that offers users personalized budgeting, investment, and savings advice. The platform will integrate with multiple banking APIs to aggregate financial data, provide real-time analytics, and offer actionable insights. It must ensure high-level security for user data and comply with financial regulations. This project aims to empower users to make informed financial decisions, improve their financial literacy, and achieve their financial goals through advanced AI and financial data integration, ultimately transforming the way individuals manage their personal finances in the digital age. The project duration is estimated to be 18 months, focusing on delivering a high-impact, value-driven solution for the personal finance management market and its stakeholders, while also addressing critical issues of data privacy and security in the digital age. By leveraging the latest AI and integration technologies, the platform will be able to provide a truly innovative and transformative financial management solution that meets the evolving needs of today's digital consumers and their stakeholders, while also addressing the critical issues of data privacy and security in the financial sector. By focusing on these key areas, the project will be able to deliver a high-impact, value-driven solution that empowers individuals to take control of their financial futures and achieve their financial goals, ultimately transforming the way personal finance management is conducted in the digital age.\n\nThe project will involve the following key roles: AI Specialist, Financial Analyst, UI/UX Designer, Data Security Expert, and Project Manager. The project will be executed in three main phases: 1) System Design and Architecture, 2) Development and Integration, and 3) Testing and Deployment. The project will also involve extensive stakeholder engagement and collaboration with financial institutions, regulatory bodies, and technology partners to ensure the platform meets the diverse needs and requirements of personal finance management stakeholders. The project will prioritize data privacy and security throughout the development process, with robust measures in place to protect sensitive information and comply with relevant data protection regulations.\n\nUltimately, this project represents a significant opportunity to transform the way personal finance management is conducted
#                            ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# ## Exportation

# %% [markdown]
# ### Deduplication

# %%
# Remove duplicate projects based on descriptive_summary
unique_projects = []
seen_summaries = set()

for project in projects_data:
    summary = project.get('descriptive_summary', '')
    if summary not in seen_summaries:
        unique_projects.append(project)
        seen_summaries.add(summary)

print(f"Before deduplication: {len(projects_data)} projects")
print(f"After deduplication: {len(unique_projects)} projects")
print(f"Removed {len(projects_data) - len(unique_projects)} duplicates")

# Update projects_data with unique projects
projects_data = unique_projects
# Out:
# Before deduplication: 85 projects
# After deduplication: 45 projects
# Removed 40 duplicates

# %% [markdown]
# ### Save final dataset as external file

# %%
import json

# Export projects_data to JSON file
with open('projects_data_en.json', 'w') as f:
    json.dump(projects_data, f, indent=2)

print(f"Exported {len(projects_data)} projects to projects_data_en.json")
# Out:
# Exported 45 projects to projects_data_en.json
